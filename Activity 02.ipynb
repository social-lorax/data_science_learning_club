# %% [markdown]
# <img src="https://i.pinimg.com/originals/e1/59/a9/e159a96d9c810ad7cf16a4b0c9f4df46.jpg" alt="" style="float:left;width:300px">
# <br />
# <br />
# <br />
# <br />
# <br />
# # Activity 2: Visuals for Exploratory Data Analysis

# %% [markdown]
# For Learning Club Activity 2, we will be learning how to create different visuals that help explore a dataset to better understand its contents. There are some "rules" of creating visualizations when they are intended for communicating the result of an analysis with others or for publication, but at this stage of exploratory data analysis, the data visualizations are for us, the analysts.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
demos = pd.read_csv('Demographic_Statistics_By_Zip_Code.csv')
demos.head()
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10002                  35            19            0.54
# 2              10003                   1             1            1.00
# 3              10004                   0             0            0.00
# 4              10005                   2             2            1.00
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# 1          16          0.46                     0                       0
# 2           0          0.00                     0                       0
# 3           0          0.00                     0                       0
# 4           0          0.00                     0                       0
#
#    COUNT GENDER TOTAL  PERCENT GENDER TOTAL               ...                 \
# ...

# %%
zips = pd.read_csv('zips.csv')

# %%
coded_data = demos.merge(zips,left_on='JURISDICTION NAME',right_on='Zip')
coded_data.head()
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10001                  44            22            0.50
# 2              10002                  35            19            0.54
# 3              10002                  35            19            0.54
# 4              10003                   1             1            1.00
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# 1          22          0.50                     0                       0
# 2          16          0.46                     0                       0
# 3          16          0.46                     0                       0
# 4           0          0.00                     0                       0
#
#    COUNT GENDER TOTAL  PERCENT GENDER TOTAL    ...      \
# ...

# %% [markdown]
# # $Scatterplot$ $Matrix$

# %%
interesting_columns = ['Boro','PERCENT FEMALE','PERCENT WHITE NON HISPANIC','PERCENT PERMANENT RESIDENT ALIEN',
                       'PERCENT RECEIVES PUBLIC ASSISTANCE']
visual = coded_data[interesting_columns].dropna(how='any')

# %%
sns.set(style="ticks")
sns.pairplot(visual, hue='Boro',height=4)
# Out:
# c:\users\owner\anaconda3\envs\thom\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# c:\users\owner\anaconda3\envs\thom\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# # $Boxplots$

# %%
coded_data[['PERCENT MALE','Boro']].boxplot(by='Boro')

# %% [markdown]
# # $Histograms$

# %%
coded_data[['PERCENT US CITIZEN']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000D2CA9F9C50>]],
#       dtype=object)
